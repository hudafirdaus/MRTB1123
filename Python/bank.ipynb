# %%
# import python library for data frame 
import pandas as pd
import scipy.stats as st

# %%
#read excel file
bank = pd.read_excel('E:\Python\Data\Banks.xlsx')

# %%
#showing the header of data file
bank.head()

#descriptive statistics information
bank.describe().T
# Out:
#            count          mean           std     min     25%      50%  \
# Revenues    51.0   6354.705882   7457.656896  1047.0  1835.5   3428.0
# Profits     51.0    803.431373    881.812321    75.0   235.5    401.0
# Employees   51.0  21530.274510  21269.354001  3884.0  7733.0  11000.0
#
#                75%      max
# Revenues    6884.0  34697.0
# Profits      985.5   3708.0
# Employees  25336.0  93700.0

# %%
bank['Revenues_Z']=st.zscore(bank['Revenues']).round(4)
bank['Profits_Z']=st.zscore(bank['Profits']).round(4)
bank['Employees_Z']=st.zscore(bank['Employees']).round(4)
bank
# Out:
#                          Name  Revenues  Profits  Employees  Revenues_Z  \
# 0                    CITICORP     34697     3591      93700      3.8382
# 1       CHASE MANHATTAN CORP.     30381     3708      69033      3.2538
# 2           BANKAMERICA CORP.     23585     3210      77000      2.3334
# 3           NATIONSBANK CORP.     21734     3077      80360      2.0827
# 4            J.P.MORGAN & CO.     17701     1465      16943      1.5366
# 5           FIRST UNION CORP.     14329     1896      43933      1.0799
# 6              BANC ONE CORP.     13219     1306      56600      0.9296
# 7    BANKERS TRUST N.Y. CORP.     12176      866      18286      0.7883
# 8     FIRST CHICAGO NBD CORP.     10098     1525      33962      0.5069
# 9               NORWEST CORP.      9660     1351      55729      0.4476
# 10          WELLS FARGO & CO.      9608     1155      33100      0.4406
# 11      FLEET FINANCIAL GROUP      8095     1303      32317      0.2357
# ...

# %%
bank
# Out:
#                          Name  Revenues  Profits  Employees  Revenues_Z  \
# 0                    CITICORP     34697     3591      93700      3.8382
# 1       CHASE MANHATTAN CORP.     30381     3708      69033      3.2538
# 2           BANKAMERICA CORP.     23585     3210      77000      2.3334
# 3           NATIONSBANK CORP.     21734     3077      80360      2.0827
# 4            J.P.MORGAN & CO.     17701     1465      16943      1.5366
# 5           FIRST UNION CORP.     14329     1896      43933      1.0799
# 6              BANC ONE CORP.     13219     1306      56600      0.9296
# 7    BANKERS TRUST N.Y. CORP.     12176      866      18286      0.7883
# 8     FIRST CHICAGO NBD CORP.     10098     1525      33962      0.5069
# 9               NORWEST CORP.      9660     1351      55729      0.4476
# 10          WELLS FARGO & CO.      9608     1155      33100      0.4406
# 11      FLEET FINANCIAL GROUP      8095     1303      32317      0.2357
# ...
